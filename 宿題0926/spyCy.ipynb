# %%
import spacy

nlp = spacy.load("en_core_web_sm")
print(nlp)
# Out:
# <spacy.lang.en.English object at 0x78fe21f72420>

# %%
# !pip install ja_ginza
# Out:
# Collecting ja_ginza
#   Downloading ja_ginza-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /usr/local/lib/python3.12/dist-packages (from ja_ginza) (3.8.7)
# Collecting sudachipy<0.7.0,>=0.6.2 (from ja_ginza)
#   Downloading SudachiPy-0.6.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting sudachidict-core>=20210802 (from ja_ginza)
#   Downloading sudachidict_core-20250825-py3-none-any.whl.metadata (2.7 kB)
# Collecting ginza<5.3.0,>=5.2.0 (from ja_ginza)
#   Downloading ginza-5.2.0-py3-none-any.whl.metadata (448 bytes)
# Collecting plac>=1.3.3 (from ginza<5.3.0,>=5.2.0->ja_ginza)
#   Downloading plac-1.4.5-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (0.17.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.11.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (2025.8.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.4.4->ja_ginza) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.4.4->ja_ginza) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja_ginza) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja_ginza) (7.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy<4.0.0,>=3.4.4->ja_ginza) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.17.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (0.1.2)
# Downloading ja_ginza-5.2.0-py3-none-any.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 15.2 MB/s eta 0:00:00
# Downloading ginza-5.2.0-py3-none-any.whl (21 kB)
# Downloading sudachidict_core-20250825-py3-none-any.whl (72.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 8.6 MB/s eta 0:00:00
# Downloading SudachiPy-0.6.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.4 MB/s eta 0:00:00
# Downloading plac-1.4.5-py2.py3-none-any.whl (22 kB)
# Installing collected packages: sudachipy, plac, sudachidict-core, ginza, ja_ginza
# Successfully installed ginza-5.2.0 ja_ginza-5.2.0 plac-1.4.5 sudachidict-core-20250825 sudachipy-0.6.10

# %%
import spacy

nlp = spacy.load('ja_ginza')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3157591661.py in <cell line: 0>()
#       1 import spacy
#       2
# ----> 3 nlp = spacy.load('ja_ginza')
#
# /usr/local/lib/python3.12/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#      50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
#     475             return get_lang_class(name.replace("blank:", ""))()
#     476         if is_package(name):  # installed as package
# --> 477             return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     478         if Path(name).exists():  # path to model data directory
#     479             return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     511     """
#     512     cls = importlib.import_module(name)
# --> 513     return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)  # type: ignore[attr-defined]
#     514
#     515
#
# /usr/local/lib/python3.12/dist-packages/ja_ginza/__init__.py in load(**overrides)
#       8
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     692     if not model_path.exists():
#     693         raise IOError(Errors.E052.format(path=data_path))
# --> 694     return load_model_from_path(
#     695         data_path,
#     696         vocab=vocab,
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     549     overrides = dict_to_dot(config, for_overrides=True)
#     550     config = load_config(config_path, overrides=overrides)
# --> 551     nlp = load_model_from_config(
#     552         config,
#     553         vocab=vocab,
#
# /usr/local/lib/python3.12/dist-packages/spacy/util.py in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     597     # registry, including custom subclasses provided via entry points
#     598     lang_cls = get_lang_class(nlp_config["lang"])
# --> 599     nlp = lang_cls.from_config(
#     600         config,
#     601         vocab=vocab,
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1891                     # The pipe name (key in the config) here is the unique name
#    1892                     # of the component, not necessarily the factory
# -> 1893                     nlp.add_pipe(
#    1894                         factory,
#    1895                         name=pipe_name,
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     823             )
#     824         else:
# --> 825             pipe_component = self.create_pipe(
#     826                 factory_name,
#     827                 name=name,
#
# /usr/local/lib/python3.12/dist-packages/spacy/language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     692                 lang_code=self.lang,
#     693             )
# --> 694             raise ValueError(err)
#     695         pipe_meta = self.get_factory_meta(factory_name)
#     696         # This is unideal, but the alternative would mean you always need to
#
# ValueError: [E002] Can't find factory for 'compound_splitter' for language Japanese (ja). This usually happens when spaCy calls `nlp.create_pipe` with a custom component name that's not registered on the current language class. If you're using a custom component, make sure you've added the decorator `@Language.component` (for function components) or `@Language.factory` (for class components).
#
# Available factories: merge_noun_chunks, merge_entities, merge_subtokens, en.lemmatizer, ja.morphologizer

# %%
# !pip install ja_ginza
# Out:
# Requirement already satisfied: ja_ginza in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /usr/local/lib/python3.12/dist-packages (from ja_ginza) (3.8.7)
# Requirement already satisfied: sudachipy<0.7.0,>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from ja_ginza) (0.6.10)
# Requirement already satisfied: sudachidict-core>=20210802 in /usr/local/lib/python3.12/dist-packages (from ja_ginza) (20250825)
# Requirement already satisfied: ginza<5.3.0,>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from ja_ginza) (5.2.0)
# Requirement already satisfied: plac>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from ginza<5.3.0,>=5.2.0->ja_ginza) (1.4.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (0.17.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (2.11.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy<4.0.0,>=3.4.4->ja_ginza) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja_ginza) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja_ginza) (2025.8.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.4.4->ja_ginza) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.0.0,>=3.4.4->ja_ginza) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja_ginza) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja_ginza) (7.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy<4.0.0,>=3.4.4->ja_ginza) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja_ginza) (1.17.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja_ginza) (0.1.2)

# %%
import spacy

nlp = spacy.load('ja_ginza')

# %%
text = """
        プログラムは、高速処理ができます。私たち人間も、決して処理が遅いというわけではありません。
        2019年に開催された全日本珠算選手権大会の「フラッシュ暗算競技」部門では、画面に次々と表示される3桁の数字、15個を加算して答えを求めるという問題が出されました。
        この大会の優勝者は、この問題をわずか「1.66秒」で成功させました。これは驚くべきスピードであり、人間のさらなる可能性を感じさせるものでした。
        しかし富士通が開発した世界一のスパコンである「富岳」は、1秒間で41.5京回(京は1兆の1万倍)の処理を行うことに成功しました。これはどんなに計算が得意な人間であっても、到底かなわない圧倒的なスピードです。
        まさに、プログラムならではの「できること」だといえるでしょう。
      """
doc = nlp(text)

for token in doc:
  print(token.text, type(token))
# Out:
#          <class 'spacy.tokens.token.Token'>
# プログラム <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 高速 <class 'spacy.tokens.token.Token'>
# 処理 <class 'spacy.tokens.token.Token'>
# が <class 'spacy.tokens.token.Token'>
# でき <class 'spacy.tokens.token.Token'>
# ます <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
# 私たち <class 'spacy.tokens.token.Token'>
# 人間 <class 'spacy.tokens.token.Token'>
# も <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 決して <class 'spacy.tokens.token.Token'>
# 処理 <class 'spacy.tokens.token.Token'>
# が <class 'spacy.tokens.token.Token'>
# 遅い <class 'spacy.tokens.token.Token'>
# と <class 'spacy.tokens.token.Token'>
# いう <class 'spacy.tokens.token.Token'>
# わけ <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# あり <class 'spacy.tokens.token.Token'>
# ませ <class 'spacy.tokens.token.Token'>
# ん <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
#
#          <class 'spacy.tokens.token.Token'>
# 2019 <class 'spacy.tokens.token.Token'>
# 年 <class 'spacy.tokens.token.Token'>
# に <class 'spacy.tokens.token.Token'>
# 開催 <class 'spacy.tokens.token.Token'>
# さ <class 'spacy.tokens.token.Token'>
# れ <class 'spacy.tokens.token.Token'>
# た <class 'spacy.tokens.token.Token'>
# 全日本 <class 'spacy.tokens.token.Token'>
# 珠算 <class 'spacy.tokens.token.Token'>
# 選手権 <class 'spacy.tokens.token.Token'>
# 大会 <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# 「 <class 'spacy.tokens.token.Token'>
# フラッシュ <class 'spacy.tokens.token.Token'>
# 暗算 <class 'spacy.tokens.token.Token'>
# 競技 <class 'spacy.tokens.token.Token'>
# 」 <class 'spacy.tokens.token.Token'>
# 部門 <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 画面 <class 'spacy.tokens.token.Token'>
# に <class 'spacy.tokens.token.Token'>
# 次々 <class 'spacy.tokens.token.Token'>
# と <class 'spacy.tokens.token.Token'>
# 表示 <class 'spacy.tokens.token.Token'>
# さ <class 'spacy.tokens.token.Token'>
# れる <class 'spacy.tokens.token.Token'>
# 3 <class 'spacy.tokens.token.Token'>
# 桁 <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# 数字 <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 15 <class 'spacy.tokens.token.Token'>
# 個 <class 'spacy.tokens.token.Token'>
# を <class 'spacy.tokens.token.Token'>
# 加算 <class 'spacy.tokens.token.Token'>
# し <class 'spacy.tokens.token.Token'>
# て <class 'spacy.tokens.token.Token'>
# 答え <class 'spacy.tokens.token.Token'>
# を <class 'spacy.tokens.token.Token'>
# 求める <class 'spacy.tokens.token.Token'>
# と <class 'spacy.tokens.token.Token'>
# いう <class 'spacy.tokens.token.Token'>
# 問題 <class 'spacy.tokens.token.Token'>
# が <class 'spacy.tokens.token.Token'>
# 出さ <class 'spacy.tokens.token.Token'>
# れ <class 'spacy.tokens.token.Token'>
# まし <class 'spacy.tokens.token.Token'>
# た <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
#
#          <class 'spacy.tokens.token.Token'>
# この <class 'spacy.tokens.token.Token'>
# 大会 <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# 優勝者 <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# この <class 'spacy.tokens.token.Token'>
# 問題 <class 'spacy.tokens.token.Token'>
# を <class 'spacy.tokens.token.Token'>
# わずか <class 'spacy.tokens.token.Token'>
# 「 <class 'spacy.tokens.token.Token'>
# 1.66 <class 'spacy.tokens.token.Token'>
# 秒 <class 'spacy.tokens.token.Token'>
# 」 <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# 成功 <class 'spacy.tokens.token.Token'>
# さ <class 'spacy.tokens.token.Token'>
# せ <class 'spacy.tokens.token.Token'>
# まし <class 'spacy.tokens.token.Token'>
# た <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
# これ <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# 驚く <class 'spacy.tokens.token.Token'>
# べき <class 'spacy.tokens.token.Token'>
# スピード <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# あり <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 人間 <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# さらなる <class 'spacy.tokens.token.Token'>
# 可能性 <class 'spacy.tokens.token.Token'>
# を <class 'spacy.tokens.token.Token'>
# 感じ <class 'spacy.tokens.token.Token'>
# させる <class 'spacy.tokens.token.Token'>
# もの <class 'spacy.tokens.token.Token'>
# でし <class 'spacy.tokens.token.Token'>
# た <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
#
#          <class 'spacy.tokens.token.Token'>
# しかし <class 'spacy.tokens.token.Token'>
# 富士通 <class 'spacy.tokens.token.Token'>
# が <class 'spacy.tokens.token.Token'>
# 開発 <class 'spacy.tokens.token.Token'>
# し <class 'spacy.tokens.token.Token'>
# た <class 'spacy.tokens.token.Token'>
# 世界一 <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# スパコン <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# ある <class 'spacy.tokens.token.Token'>
# 「 <class 'spacy.tokens.token.Token'>
# 富岳 <class 'spacy.tokens.token.Token'>
# 」 <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 1 <class 'spacy.tokens.token.Token'>
# 秒間 <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# 41.5 <class 'spacy.tokens.token.Token'>
# 京 <class 'spacy.tokens.token.Token'>
# 回 <class 'spacy.tokens.token.Token'>
# ( <class 'spacy.tokens.token.Token'>
# 京 <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# 1兆 <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# 1万 <class 'spacy.tokens.token.Token'>
# 倍 <class 'spacy.tokens.token.Token'>
# ) <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# 処理 <class 'spacy.tokens.token.Token'>
# を <class 'spacy.tokens.token.Token'>
# 行う <class 'spacy.tokens.token.Token'>
# こと <class 'spacy.tokens.token.Token'>
# に <class 'spacy.tokens.token.Token'>
# 成功 <class 'spacy.tokens.token.Token'>
# し <class 'spacy.tokens.token.Token'>
# まし <class 'spacy.tokens.token.Token'>
# た <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
# これ <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# どんな <class 'spacy.tokens.token.Token'>
# に <class 'spacy.tokens.token.Token'>
# 計算 <class 'spacy.tokens.token.Token'>
# が <class 'spacy.tokens.token.Token'>
# 得意 <class 'spacy.tokens.token.Token'>
# な <class 'spacy.tokens.token.Token'>
# 人間 <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# あっ <class 'spacy.tokens.token.Token'>
# て <class 'spacy.tokens.token.Token'>
# も <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# 到底 <class 'spacy.tokens.token.Token'>
# かなわ <class 'spacy.tokens.token.Token'>
# ない <class 'spacy.tokens.token.Token'>
# 圧倒的 <class 'spacy.tokens.token.Token'>
# な <class 'spacy.tokens.token.Token'>
# スピード <class 'spacy.tokens.token.Token'>
# です <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
#
#          <class 'spacy.tokens.token.Token'>
# まさに <class 'spacy.tokens.token.Token'>
# 、 <class 'spacy.tokens.token.Token'>
# プログラム <class 'spacy.tokens.token.Token'>
# なら <class 'spacy.tokens.token.Token'>
# で <class 'spacy.tokens.token.Token'>
# は <class 'spacy.tokens.token.Token'>
# の <class 'spacy.tokens.token.Token'>
# 「 <class 'spacy.tokens.token.Token'>
# できる <class 'spacy.tokens.token.Token'>
# こと <class 'spacy.tokens.token.Token'>
# 」 <class 'spacy.tokens.token.Token'>
# だ <class 'spacy.tokens.token.Token'>
# と <class 'spacy.tokens.token.Token'>
# いえる <class 'spacy.tokens.token.Token'>
# でしょう <class 'spacy.tokens.token.Token'>
# 。 <class 'spacy.tokens.token.Token'>
#
#        <class 'spacy.tokens.token.Token'>

# %%
from spacy import displacy

displacy.render(doc, style="ent", options={"compact":True},  jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>        プログラムは、高速処理ができます。私たち
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     人間
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mammal</span>
# </mark>
# も、決して処理が遅いというわけではありません。<br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# に開催された
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     全日本珠算選手権大会
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Game</span>
# </mark>
# の「
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     フラッシュ暗算競技
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Music</span>
# </mark>
# 」部門では、画面に次々と表示される
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3桁
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Product</span>
# </mark>
# の数字、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15個
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Product</span>
# </mark>
# を加算して答えを求めるという問題が出されました。<br>        この大会の優勝者は、この問題をわずか「
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.66秒
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Time</span>
# </mark>
# 」で成功させました。これは驚くべきスピードであり、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     人間
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mammal</span>
# </mark>
# のさらなる可能性を感じさせるものでした。<br>        しかし
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     富士通
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Person</span>
# </mark>
# が開発した世界一のスパコンである「
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     富岳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Offense</span>
# </mark>
# 」は、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1秒間
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Time</span>
# </mark>
# で
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     41.5京回
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Compound</span>
# </mark>
# (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     京
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1兆
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1万倍
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Multiplication</span>
# </mark>
# )の処理を行うことに成功しました。これはどんなに計算が得意な人間であっても、到底かなわない圧倒的なスピードです。<br>        まさに、プログラムならではの「できること」だといえるでしょう。<br>      </div></span>
